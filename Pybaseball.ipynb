# %% [markdown]
# # Working with Pybaseball

# %% [markdown]
# ### Gabe Rice
# ### Stats 336
# ### 3/25/25

# %% [markdown]
# It seems the closest thing to Lahman is the Python library pybaseball. Here's a link to the github page contaning more information then i'm going to type here: https://github.com/jldbc/pybaseball/tree/master. Going to start by replicating some things then moving onto creating queries more similar to the ones we've done in class.

# %% [markdown]
# Type into consle

# %%
pip install pybaseball

# %% [markdown]
# Working through some online information

# %%
from pybaseball import statcast
data = statcast(start_dt='2017-06-24', end_dt='2017-06-27')
data.head(2)
# Out:
# This is a large query, it may take a moment to complete
#   0%|                                                     | 0/4 [00:00<?, ?it/s]/Users/gabrielrice/miniforge3/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  25%|███████████▎                                 | 1/4 [00:00<00:01,  2.24it/s]/Users/gabrielrice/miniforge3/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ...

# %%
from pybaseball import playerid_lookup
from pybaseball import statcast_pitcher
playerid_lookup('kershaw', 'clayton')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   kershaw    clayton     477132  kersc001  kershcl01           2036
#
#    mlb_played_first  mlb_played_last
# 0            2008.0           2024.0

# %% [markdown]
# Seems to be working going to look into doing some batting queries

# %%
from pybaseball import batting_stats

# get all of this season's batting data so far
data = batting_stats(2017)

data.head(10)
# Out:
#      IDfg  Season               Name Team  Age    G   AB   PA    H   1B  ...  \
# 1   15640    2017        Aaron Judge  NYY   25  155  542  678  154   75  ...
# 6    5417    2017        Jose Altuve  HOU   27  153  590  662  204  137  ...
# 11  13510    2017       Jose Ramirez  CLE   24  152  585  645  186   95  ...
# 9   15429    2017        Kris Bryant  CHC   25  151  549  665  162   91  ...
# 0   10155    2017         Mike Trout  LAA   25  114  402  507  123   62  ...
# 4    4949    2017  Giancarlo Stanton  MIA   27  159  597  692  168   77  ...
# 2    4314    2017         Joey Votto  CIN   33  162  559  707  179  108  ...
# 37   9810    2017       Brian Dozier  MIN   30  152  617  705  167   99  ...
# 13  12861    2017     Anthony Rendon  WSN   27  147  508  605  153   86  ...
# 12   9777    2017      Nolan Arenado  COL   26  159  606  680  187  100  ...
#
#     maxEV  HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  L-WAR
# ...
